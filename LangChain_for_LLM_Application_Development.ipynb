# %%
# !pip install python-dotenv openai langchain --quiet

# %%
import os

# Remplace "TA_NOUVELLE_CLÉ_API" par ta vraie clé API OpenAI
os.environ["OPENAI_API_KEY"] = "..."

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# False

# %%
import openai
import datetime

# Définir le modèle selon la date
current_date = datetime.datetime.now().date()
target_date = datetime.date(2024, 6, 12)

if current_date > target_date:
    llm_model = "gpt-3.5-turbo"
else:
    llm_model = "gpt-3.5-turbo-0301"

# %%
def get_completion(prompt, model=llm_model):
    messages = [{"role": "user", "content": prompt}]
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=0,
    )
    return response.choices[0].message["content"]

print(get_completion("What is 1+1?"))  # Test simple
# Out:
# ---------------------------------------------------------------------------
# APIRemovedInV1                            Traceback (most recent call last)
# <ipython-input-16-6a2928a8bc49> in <cell line: 0>()
#       8     return response.choices[0].message["content"]
#       9
# ---> 10 print(get_completion("What is 1+1?"))  # Test simple
#
# <ipython-input-16-6a2928a8bc49> in get_completion(prompt, model)
#       1 def get_completion(prompt, model=llm_model):
#       2     messages = [{"role": "user", "content": prompt}]
# ----> 3     response = openai.ChatCompletion.create(
#       4         model=model,
#       5         messages=messages,
#
# /usr/local/lib/python3.11/dist-packages/openai/lib/_old_api.py in __call__(self, *_args, **_kwargs)
#      37
#      38     def __call__(self, *_args: Any, **_kwargs: Any) -> Any:
# ---> 39         raise APIRemovedInV1(symbol=self._symbol)
#      40
#      41
#
# APIRemovedInV1:
#
# ...

# %%
# !pip install --upgrade openai

# %%
import os
import openai
import datetime

# Définir la clé API (ne pas la partager publiquement !)
os.environ["OPENAI_API_KEY"] = "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"

# Créer un client OpenAI
client = openai.OpenAI(api_key=os.environ["OPENAI_API_KEY"])

# Définir le modèle selon la date
current_date = datetime.datetime.now().date()
target_date = datetime.date(2024, 6, 12)

if current_date > target_date:
    llm_model = "gpt-3.5-turbo"
else:
    llm_model = "gpt-3.5-turbo-0301"

# Fonction pour générer une réponse avec le modèle LLM
def get_completion(prompt, model=llm_model):
    messages = [{"role": "user", "content": prompt}]
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=0,
    )
    return response.choices[0].message.content

# Test simple
print(get_completion("What is 1+1?"))
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# <ipython-input-19-33af949dacbf> in <cell line: 0>()
#      29
#      30 # Test simple
# ---> 31 print(get_completion("What is 1+1?"))
#
# <ipython-input-19-33af949dacbf> in get_completion(prompt, model)
#      21 def get_completion(prompt, model=llm_model):
#      22     messages = [{"role": "user", "content": prompt}]
# ---> 23     response = client.chat.completions.create(
#      24         model=model,
#      25         messages=messages,
#
# /usr/local/lib/python3.11/dist-packages/openai/_utils/_utils.py in wrapper(*args, **kwargs)
#     277                         msg = f"Missing required argument: {quote(missing[0])}"
#     278                 raise TypeError(msg)
# --> 279             return func(*args, **kwargs)
#     280
#     281         return wrapper  # type: ignore
#
# ...
